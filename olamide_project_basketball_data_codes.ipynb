# %% [markdown]
# <a href="https://colab.research.google.com/github/LammyG/AdaBoost/blob/main/olamide_project_basketball_data_codes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install oi
import numpy as np
import pandas as pd
from google.colab import files
uploaded = files.upload()
import io
bb_master = pd.read_csv('bb_master.csv')
bb_teams = pd.read_csv('bb_teams.csv')
bb_player_allstar = pd.read_csv('bb_player_allstar.csv')
bb_coaches = pd.read_csv('bb_coaches.csv')
bb_series_post = pd.read_csv('bb_series_post.csv')
# Out:
# ...
#      |████████████████████████████████| 154 kB 5.4 MB/s
# ...
#      |████████████████████████████████| 138 kB 45.0 MB/s
# ...
#   Created wheel for oi: filename=oi-0.4.2-py3-none-any.whl size=9524 sha256=7c070517a5059d2ad187e7303e67598c466d7945adbd848a0c688a133ca0a568
#   Stored in directory: /root/.cache/pip/wheels/aa/bb/c8/25c36d15af7c36ea84b1c0f6209e110e0d105ad5656709dea4
# ...
#   Created wheel for nanomsg: filename=nanomsg-1.0-cp37-cp37m-linux_x86_64.whl size=8165 sha256=88ea2e83daabe13ca66e880b6b85f449918969e4862f261cfabb0cd26bb00360
#   Stored in directory: /root/.cache/pip/wheels/5b/82/e0/f80d5dfc29a95891f032640e1ddd0bb747bff95b4da413edc1
# ...
#   Created wheel for nanoservice: filename=nanoservice-0.7.2-py2.py3-none-any.whl size=13020 sha256=75a40cd8d149695e6010dfe4e086a376289bff67b5bce40ca14edb6152a479c4
#   Stored in directory: /root/.cache/pip/wheels/74/f8/75/4e6c3e17891dadd335914a6c71c9af6141584587aa9524ea52
# ...

# %%
from google.colab import files
uploaded = files.upload()
import io
bb_hof = pd.read_csv('bb_hof.csv')
bb_draft = pd.read_csv('bb_draft.csv')
bb_abbrev = pd.read_csv('bb_abbrev.csv')
bb_awards_players = pd.read_csv('bb_awards_players.csv')
bb_awards_coaches = pd.read_csv('bb_awards_coaches.csv')
# Out:
#      <input type="file" id="files-059f1179-753a-420a-a5bb-71d186393917" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-059f1179-753a-420a-a5bb-71d186393917">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bb_awards_players.csv to bb_awards_players.csv
# Saving bb_draft.csv to bb_draft.csv
# Saving bb_hof.csv to bb_hof.csv
# Saving bb_abbrev.csv to bb_abbrev.csv
# Saving bb_awards_coaches.csv to bb_awards_coaches.csv

# %%
bb_master.columns
# Out:
# Index(['bioID', 'useFirst', 'firstName', 'middleName', 'lastName', 'nameGiven',
#        'fullGivenName', 'nameSuffix', 'nameNick', 'pos', 'firstseason',
#        'lastseason', 'height', 'weight', 'college', 'collegeOther',
#        'birthDate', 'birthCity', 'birthState', 'birthCountry', 'highSchool',
#        'hsCity', 'hsState', 'hsCountry', 'deathDate', 'race'],
#       dtype='object')

# %%
bb_master.columns = bb_master.columns.str.upper()

# %%
bb_master.head()
# Out:
#        BIOID USEFIRST FIRSTNAME MIDDLENAME  ...  HSSTATE HSCOUNTRY   DEATHDATE RACE
# 0  abdelal01     Alaa      Alaa        NaN  ...       NJ       USA  0000-00-00    B
# 1  abdulka01   Kareem    Kareem        NaN  ...       NY       USA  0000-00-00    B
# 2  abdulma01    Mahdi     Mahdi        NaN  ...  PA / MD       USA  2011-11-18    B
# 3  abdulma02  Mahmoud   Mahmoud        NaN  ...       MS       USA  0000-00-00    B
# 4  abdulta01    Tariq     Tariq        NaN  ...      NaN       FRA  0000-00-00    B
#
# [5 rows x 26 columns]

# %%
bb_hof.columns
# Out:
# Index(['YEAR', 'HOFID', 'NAME', 'CATEGORY'], dtype='object')

# %%
bb_hof.columns = bb_hof.columns.str.upper()

# %%
bb_master.isnull()
# Out:
#       BIOID  USEFIRST  FIRSTNAME  ...  HSCOUNTRY  DEATHDATE   RACE
# 0     False     False      False  ...      False      False  False
# 1     False     False      False  ...      False      False  False
# 2     False     False      False  ...      False      False  False
# 3     False     False      False  ...      False      False  False
# 4     False     False      False  ...      False      False  False
# ...     ...       ...        ...  ...        ...        ...    ...
# 5056  False     False      False  ...       True      False   True
# 5057  False     False      False  ...       True      False   True
# 5058  False     False      False  ...       True      False   True
# 5059  False     False      False  ...       True      False   True
# 5060  False     False      False  ...       True      False   True
#
# [5061 rows x 26 columns]

# %%
bb_hof.head()
# Out:
#    YEAR      HOFID               NAME     CATEGORY
# 0  1959        NaN  Amos Alonzo Stagg  Contributor
# 1  1959        NaN      Charles Hyatt       Player
# 2  1959        NaN      Edward Hickox  Contributor
# 3  1959  mikange01       George Mikan       Player
# 4  1959        NaN      Hank Luisetti       Player

# %%
bb_master.isnull().any()
# Out:
# BIOID            False
# USEFIRST          True
# FIRSTNAME         True
# MIDDLENAME        True
# LASTNAME         False
# NAMEGIVEN         True
# FULLGIVENNAME     True
# NAMESUFFIX        True
# NAMENICK          True
# POS               True
# FIRSTSEASON       True
# LASTSEASON        True
# HEIGHT            True
# WEIGHT            True
# COLLEGE           True
# COLLEGEOTHER      True
# BIRTHDATE         True
# BIRTHCITY         True
# BIRTHSTATE        True
# BIRTHCOUNTRY      True
# HIGHSCHOOL        True
# HSCITY            True
# HSSTATE           True
# HSCOUNTRY         True
# DEATHDATE        False
# RACE              True
# dtype: bool

# %%
bb_master.isnull().any().any()
# Out:
# True

# %%
bb_master.isnull().sum()
# Out:
# BIOID               0
# USEFIRST          831
# FIRSTNAME          24
# MIDDLENAME       1816
# LASTNAME            0
# NAMEGIVEN        5052
# FULLGIVENNAME    5035
# NAMESUFFIX       4738
# NAMENICK         2354
# POS               182
# FIRSTSEASON        15
# LASTSEASON         15
# HEIGHT             13
# WEIGHT             14
# COLLEGE           178
# COLLEGEOTHER     4208
# BIRTHDATE          11
# BIRTHCITY        1174
# BIRTHSTATE       1454
# BIRTHCOUNTRY     1160
# HIGHSCHOOL        773
# HSCITY            765
# HSSTATE           834
# HSCOUNTRY         765
# DEATHDATE           0
# RACE              159
# dtype: int64

# %%
bb_master.isnull().sum().sum()
# Out:
# 31570

# %%
bb_master.head()
# Out:
#        BIOID USEFIRST FIRSTNAME MIDDLENAME  ...  HSSTATE HSCOUNTRY   DEATHDATE RACE
# 0  abdelal01     Alaa      Alaa        NaN  ...       NJ       USA  0000-00-00    B
# 1  abdulka01   Kareem    Kareem        NaN  ...       NY       USA  0000-00-00    B
# 2  abdulma01    Mahdi     Mahdi        NaN  ...  PA / MD       USA  2011-11-18    B
# 3  abdulma02  Mahmoud   Mahmoud        NaN  ...       MS       USA  0000-00-00    B
# 4  abdulta01    Tariq     Tariq        NaN  ...      NaN       FRA  0000-00-00    B
#
# [5 rows x 26 columns]

# %%
bb_master.shape
# Out:
# (5061, 26)

# %%
#drop missing rows or numbers with condition(s)
bb_master.dropna(axis=1)
# Out:
#           BIOID      LASTNAME   DEATHDATE
# 0     abdelal01     Abdelnaby  0000-00-00
# 1     abdulka01  Abdul-Jabbar  0000-00-00
# 2     abdulma01  Abdul-Rahman  2011-11-18
# 3     abdulma02    Abdul-Rauf  0000-00-00
# 4     abdulta01   Abdul-Wahad  0000-00-00
# ...         ...           ...         ...
# 5056   rosegl01          Rose  0000-00-00
# 5057  shephle01      Shepherd  0000-00-00
# 5058  glammge01      Glammack  0000-00-00
# 5059  eurasge01        Eurash  0000-00-00
# 5060  koliswa01        Kolish  0000-00-00
#
# [5061 rows x 3 columns]

# %%
bb_master.dropna(axis=1).shape
# Out:
# (5061, 3)

# %%
bb_hof.isnull().any()
# Out:
# YEAR        False
# HOFID        True
# NAME        False
# CATEGORY    False
# dtype: bool

# %%
bb_hof.isnull().sum()
# Out:
# YEAR          0
# HOFID       188
# NAME          0
# CATEGORY      0
# dtype: int64

# %%
bb_hof.isnull().sum().sum()
# Out:
# 188

# %%
bb_hof.shape
# Out:
# (328, 4)

# %%
#drop missing rows with condition(s)
bb_hof.dropna(axis=1)
# Out:
#      YEAR               NAME     CATEGORY
# 0    1959  Amos Alonzo Stagg  Contributor
# 1    1959      Charles Hyatt       Player
# 2    1959      Edward Hickox  Contributor
# 3    1959       George Mikan       Player
# 4    1959      Hank Luisetti       Player
# ..    ...                ...          ...
# 323  2012     Lidia Alexeeva        Coach
# 324  2012        Mel Daniels       Player
# 325  2012        Phil Knight  Contributor
# 326  2012      Ralph Sampson       Player
# 327  2012      Reggie Miller       Player
#
# [328 rows x 3 columns]

# %%
bb_hof.dropna(axis=1).shape
# Out:
# (328, 3)

# %%
bb_master.describe()
# Out:
#        FIRSTSEASON   LASTSEASON       HEIGHT       WEIGHT
# count  5046.000000  5046.000000  5048.000000  5047.000000
# mean      0.386643     0.386643    74.269810   194.565683
# std      27.465256    27.465256    15.272533    49.357786
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000    74.000000   181.000000
# 50%       0.000000     0.000000    77.000000   200.000000
# 75%       0.000000     0.000000    80.000000   220.000000
# max    1951.000000  1951.000000    91.000000   330.000000

# %%
bb_hof.describe()
# Out:
#               YEAR
# count   328.000000
# mean   1986.161585
# std      17.113261
# min    1959.000000
# 25%    1972.000000
# 50%    1987.000000
# 75%    2001.000000
# max    2012.000000

# %%
bb_master.duplicated().any()
# Out:
# False

# %%
import numpy as np
import pandas as pd
bb_master.groupby('FULLGIVENNAME').first()
# Out:
#                                     BIOID USEFIRST  ...   DEATHDATE RACE
# FULLGIVENNAME                                       ...
# Akeem Abdul Olajuwon            olajuha01   Hakeem  ...  0000-00-00    B
# Armon Louis Gilliam             gilliar01    Armon  ...  2011-07-05    B
# Brian Carson Williams            delebi01    Bison  ...  2002-07-07    B
# Chris Wayne Jackson             abdulma02  Mahmoud  ...  0000-00-00    B
# Clifton Nathaniel               cliftna01      Nat  ...  1990-08-31    B
# Donald A. Smith                 abdulza01     Zaid  ...  0000-00-00    B
# Ed Milkovich                    melvied01       Ed  ...  2004-07-30    W
# Ferdinand Lewis Alcindor, Jr.   abdulka01   Kareem  ...  0000-00-00    B
# Gary Cole                       jeelaab01    Abdul  ...  0000-00-00    B
# Gjuro Gregorvitch Glamocli      glamage01   George  ...  1987-03-10    W
# Hashim Thabit Manka             thabeha01  Hasheem  ...  0000-00-00    B
# ...

# %%
bb_hof.duplicated().any()
# Out:
# False

# %%
bb_hof.groupby('HOFID').first()
# Out:
#            YEAR                 NAME CATEGORY
# HOFID
# abdulka01  1995  Kareem Abdul-Jabbar   Player
# archina01  1991       Tiny Archibald   Player
# arizipa01  1978          Paul Arizin   Player
# auerbre01  1969         Red Auerbach    Coach
# barklch01  2006      Charles Barkley   Player
# ...         ...                  ...      ...
# wintete01  2011           Tex Winter    Coach
# woodejo01  1960          John Wooden   Player
# woolpph01  1992     Phillip Woolpert    Coach
# worthja01  2003         James Worthy   Player
# yardlge01  1996       George Yardley   Player
#
# [136 rows x 3 columns]

# %%
bb_hof.groupby('CATEGORY').count()
# Out:
#              YEAR  HOFID  NAME
# CATEGORY
# Coach          90     24    90
# Contributor    58     10    58
# Player        157    105   157
# Referee        14      1    14
# Team            9      0     9

# %%
#Inferences from dataset
- in the bb_master dataset, there were missing datas which was dropped. notably the birthstate, birthcountry of some coaches/players were missing  ().i.e. not recorded in the dataset).
  even physical features or attributes of some players/coaches were missing.
- the dataset of bb_master consists of 5061 rows x 26 columns. However after dropping the missing columns & rows.
   we're left with 5061 rows x 3 columns of the dataset to work with.
- Likewise the bb_hof dataset which consists of 328 rows x 4 columns; there were 188 missing datas, in which after dropping them, we're left with 328rows x 3columns to work with.
- the mean of the statistics for the first season is also deduced to be same as that of last season.
  while there was an increase in the mean of this weight when compared to height.
- in the year 1959, the category of; coach, contributor, player, referee and team were all included in the hall of fame with their HOF ID inclusive.
